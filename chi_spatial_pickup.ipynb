# %%
sc

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

import seaborn as sns
sns.set(style="whitegrid")

import fiona
import fiona.crs
import shapely
import rtree

import pandas as pd
import geopandas as gpd

# %%
shapefile = 'geo_export_e9d3582a-5b2b-4f57-a181-13de90251c84.shp'
comm = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2790))
comm
# Out:
#     perimeter               community      shape_len    shape_area  area  \
# 0         0.0                 DOUGLAS   31027.054510  4.600462e+07   0.0
# 1         0.0                 OAKLAND   19565.506153  1.691396e+07   0.0
# 2         0.0             FULLER PARK   25339.089750  1.991670e+07   0.0
# 3         0.0         GRAND BOULEVARD   28196.837157  4.849250e+07   0.0
# 4         0.0                 KENWOOD   23325.167906  2.907174e+07   0.0
# 5         0.0          LINCOLN SQUARE   36624.603085  7.135233e+07   0.0
# 6         0.0         WASHINGTON PARK   28175.316087  4.237388e+07   0.0
# 7         0.0               HYDE PARK   29746.708202  4.510538e+07   0.0
# 8         0.0                WOODLAWN   46936.959244  5.781518e+07   0.0
# 9         0.0             ROGERS PARK   34052.397576  5.125990e+07   0.0
# 10        0.0          JEFFERSON PARK   44011.957170  6.486816e+07   0.0
# 11        0.0             FOREST GLEN   74493.821604  8.913089e+07   0.0
# 12        0.0              NORTH PARK   41581.948654  7.028871e+07   0.0
# 13        0.0             ALBANY PARK   39339.016439  5.354223e+07   0.0
# 14        0.0            PORTAGE PARK   46520.642138  1.101961e+08   0.0
# 15        0.0             IRVING PARK   49083.224094  8.961138e+07   0.0
# 16        0.0                 DUNNING   54555.992534  1.035950e+08   0.0
# 17        0.0               MONTCLARE   22404.852145  2.757639e+07   0.0
# 18        0.0          BELMONT CRAGIN   43311.707379  1.090994e+08   0.0
# 19        0.0              WEST RIDGE   43020.689458  9.842909e+07   0.0
# 20        0.0                 HERMOSA   27179.017438  3.260206e+07   0.0
# 21        0.0                AVONDALE   34261.933404  5.529060e+07   0.0
# 22        0.0            LOGAN SQUARE   49213.421749  1.000576e+08   0.0
# 23        0.0           HUMBOLDT PARK   48583.064330  1.004809e+08   0.0
# 24        0.0               WEST TOWN   55203.718696  1.275629e+08   0.0
# 25        0.0                  AUSTIN   75226.474917  1.992542e+08   0.0
# 26        0.0      WEST GARFIELD PARK   26238.541980  3.609285e+07   0.0
# 27        0.0      EAST GARFIELD PARK   31514.625957  5.388322e+07   0.0
# 28        0.0          NEAR WEST SIDE   53003.592941  1.584925e+08   0.0
# 29        0.0          NORTH LAWNDALE   44959.459663  8.948742e+07   0.0
# ..        ...                     ...            ...           ...   ...
# 47        0.0           SOUTH DEERING   80389.871800  3.037971e+08   0.0
# 48        0.0               EAST SIDE   52274.192849  8.324173e+07   0.0
# 49        0.0            WEST PULLMAN   50023.843001  9.936520e+07   0.0
# 50        0.0               RIVERDALE   46455.440857  9.838950e+07   0.0
# 51        0.0               HEGEWISCH   73692.382132  1.459657e+08   0.0
# 52        0.0          GARFIELD RIDGE   60080.447970  1.178908e+08   0.0
# 53        0.0          ARCHER HEIGHTS   31880.021029  5.592251e+07   0.0
# 54        0.0           BRIGHTON PARK   36537.134306  7.589279e+07   0.0
# 55        0.0           MCKINLEY PARK   26014.096837  3.943180e+07   0.0
# 56        0.0               LAKE VIEW   51973.096868  8.721480e+07   0.0
# 57        0.0              BRIDGEPORT   32732.718327  5.829152e+07   0.0
# 58        0.0                NEW CITY   48133.595961  1.346370e+08   0.0
# 59        0.0             WEST ELSDON   26229.695601  3.271109e+07   0.0
# 60        0.0               GAGE PARK   32294.195911  6.128490e+07   0.0
# 61        0.0                CLEARING   45363.286175  7.114519e+07   0.0
# 62        0.0               WEST LAWN   41934.490131  8.231530e+07   0.0
# 63        0.0            CHICAGO LAWN   40073.099838  9.827947e+07   0.0
# 64        0.0          WEST ENGLEWOOD   40195.203307  8.794769e+07   0.0
# 65        0.0               ENGLEWOOD   42316.844297  8.565232e+07   0.0
# 66        0.0  GREATER GRAND CROSSING   54645.330300  9.885317e+07   0.0
# 67        0.0            LINCOLN PARK   49478.427771  8.831640e+07   0.0
# 68        0.0                 ASHBURN   54818.154632  1.354603e+08   0.0
# 69        0.0          AUBURN GRESHAM   46757.721716  1.050654e+08   0.0
# 70        0.0                 BEVERLY   44591.485101  8.877936e+07   0.0
# 71        0.0      WASHINGTON HEIGHTS   42222.598163  7.963575e+07   0.0
# 72        0.0         MOUNT GREENWOOD   48665.130539  7.558429e+07   0.0
# 73        0.0             MORGAN PARK   46396.419362  9.187734e+07   0.0
# 74        0.0                   OHARE  173625.984660  3.718356e+08   0.0
# 75        0.0               EDGEWATER   31004.830946  4.844999e+07   0.0
# 76        0.0             EDISON PARK   25937.226841  3.163631e+07   0.0
#
#     comarea area_numbe area_num_1  comarea_id  \
# 0       0.0         35         35         0.0
# 1       0.0         36         36         0.0
# 2       0.0         37         37         0.0
# 3       0.0         38         38         0.0
# 4       0.0         39         39         0.0
# 5       0.0          4          4         0.0
# 6       0.0         40         40         0.0
# 7       0.0         41         41         0.0
# 8       0.0         42         42         0.0
# 9       0.0          1          1         0.0
# 10      0.0         11         11         0.0
# 11      0.0         12         12         0.0
# 12      0.0         13         13         0.0
# 13      0.0         14         14         0.0
# 14      0.0         15         15         0.0
# 15      0.0         16         16         0.0
# 16      0.0         17         17         0.0
# 17      0.0         18         18         0.0
# 18      0.0         19         19         0.0
# 19      0.0          2          2         0.0
# 20      0.0         20         20         0.0
# 21      0.0         21         21         0.0
# 22      0.0         22         22         0.0
# 23      0.0         23         23         0.0
# 24      0.0         24         24         0.0
# 25      0.0         25         25         0.0
# 26      0.0         26         26         0.0
# 27      0.0         27         27         0.0
# 28      0.0         28         28         0.0
# 29      0.0         29         29         0.0
# ..      ...        ...        ...         ...
# 47      0.0         51         51         0.0
# 48      0.0         52         52         0.0
# 49      0.0         53         53         0.0
# 50      0.0         54         54         0.0
# 51      0.0         55         55         0.0
# 52      0.0         56         56         0.0
# 53      0.0         57         57         0.0
# 54      0.0         58         58         0.0
# 55      0.0         59         59         0.0
# 56      0.0          6          6         0.0
# 57      0.0         60         60         0.0
# 58      0.0         61         61         0.0
# 59      0.0         62         62         0.0
# 60      0.0         63         63         0.0
# 61      0.0         64         64         0.0
# 62      0.0         65         65         0.0
# 63      0.0         66         66         0.0
# 64      0.0         67         67         0.0
# 65      0.0         68         68         0.0
# 66      0.0         69         69         0.0
# 67      0.0          7          7         0.0
# 68      0.0         70         70         0.0
# 69      0.0         71         71         0.0
# 70      0.0         72         72         0.0
# 71      0.0         73         73         0.0
# 72      0.0         74         74         0.0
# 73      0.0         75         75         0.0
# 74      0.0         76         76         0.0
# 75      0.0         77         77         0.0
# 76      0.0          9          9         0.0
#
#                                              geometry
# 0   POLYGON ((360144.2468275505 575106.3365931036,...
# 1   POLYGON ((361581.7187503375 572034.7675512792,...
# 2   POLYGON ((358550.672491759 570339.1045798016, ...
# 3   POLYGON ((360372.4794208959 572011.601851514, ...
# 4   POLYGON ((361581.7187503375 572034.7675512792,...
# 5   POLYGON ((354611.6860858612 589658.4415737576,...
# 6   POLYGON ((360457.2770231311 568575.6723627201,...
# 7   POLYGON ((362574.1809296643 570443.4162790448,...
# 8   POLYGON ((362858.783012469 568626.6409682452, ...
# 9   POLYGON ((356237.5762357235 592121.821263395, ...
# 10  POLYGON ((348134.3003302045 588707.8672889569,...
# 11  POLYGON ((346735.4299720632 592799.6216798241,...
# 12  POLYGON ((351912.8910845881 590413.184728298, ...
# 13  POLYGON ((352158.0145085152 589356.5438242608,...
# 14  POLYGON ((348134.3003302045 588707.8672889569,...
# 15  POLYGON ((352938.3278740225 587998.500441242, ...
# 16  POLYGON ((346201.0884734588 585416.1732281321,...
# 17  POLYGON ((345121.1391008406 583083.5613210419,...
# 18  POLYGON ((349112.4079248206 582708.7375263477,...
# 19  POLYGON ((353726.031557031 594470.3822586162, ...
# 20  POLYGON ((349917.7669088183 584695.5191566453,...
# 21  POLYGON ((353519.6934925151 585207.1166470201,...
# 22  POLYGON ((353949.7799542872 584779.9207923904,...
# 23  POLYGON ((353262.3444246959 579883.7311768851,...
# 24  POLYGON ((356123.223093737 582414.7910493922, ...
# 25  POLYGON ((345121.1391008406 583083.5613210419,...
# 26  POLYGON ((350897.4979324419 577830.8244259508,...
# 27  POLYGON ((353262.3444246959 579883.7311768851,...
# 28  POLYGON ((357744.2715468758 579700.7851875887,...
# 29  POLYGON ((350897.4979324419 577830.8244259508,...
# ..                                                ...
# 47  POLYGON ((365538.9643586795 561616.7185311905,...
# 48  POLYGON ((367323.4198323957 558187.7144779975,...
# 49  POLYGON ((359556.4397053752 554487.5931172645,...
# 50  POLYGON ((360922.7522987226 557509.4194920987,...
# 51  POLYGON ((367323.4198323957 558187.7144779975,...
# 52  POLYGON ((349416.1967487986 572137.5524737904,...
# 53  POLYGON ((351419.8995377243 572966.363090853, ...
# 54  POLYGON ((353925.4550977975 572647.1028318328,...
# 55  POLYGON ((356261.9633934574 572700.0003984966,...
# 56  POLYGON ((357397.6176987676 587314.3906217144,...
# 57  POLYGON ((358101.7406045345 572748.0195704472,...
# 58  POLYGON ((358003.9367640464 569510.8034979199,...
# 59  POLYGON ((351486.8728270303 570510.7320423032,...
# 60  POLYGON ((354400.7744577179 569414.9070691845,...
# 61  POLYGON ((349519.0838100119 568481.4246004804,...
# 62  POLYGON ((351626.3271526591 565336.7791857966,...
# 63  POLYGON ((354486.576073161 565393.7768997806, ...
# 64  POLYGON ((356390.3720802749 569464.1014303655,...
# 65  POLYGON ((358612.2516637176 568258.8731247808,...
# 66  POLYGON ((359665.7458674278 567943.1209988564,...
# 67  POLYGON ((358181.084074182 584852.5038149834, ...
# 68  POLYGON ((351626.3271526591 565336.7791857966,...
# 69  POLYGON ((357669.0190500504 565250.5849871836,...
# 70  POLYGON ((354926.8605232491 562953.2273244306,...
# 71  POLYGON ((358206.4770129678 562223.3933291412,...
# 72  POLYGON ((353005.5190043253 559771.8821789911,...
# 73  POLYGON ((357545.1000457324 557356.3193346474,...
# 74  (POLYGON ((341164.1100838215 590710.9937909774...
# 75  POLYGON ((356237.5762357235 592121.821263395, ...
# 76  POLYGON ((343625.5259740934 592329.7596834729,...
#
# [77 rows x 10 columns]

# %%
boros = gpd.read_file(shapefile)
# boros.set_index('BoroCode', inplace=True)
# boros.sort()
comm.plot()

# %%
rdd = sc.textFile('chi100k.csv')

# %%
def createIndex(shapefile):
    import rtree
    import fiona.crs
    import geopandas as gpd
    zones = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2790))
    index = rtree.Rtree()
    for idx,geometry in enumerate(zones.geometry):
        index.insert(idx, geometry.bounds)
    return (index, zones)

def findZone(p, index, zones):
    match = index.intersection((p.x, p.y, p.x, p.y))
    for idx in match:
        if zones.geometry[idx].contains(p):
            return idx
    return None

def processTrips(pid, records):
    import csv
    import pyproj
    import shapely.geometry as geom
    
    proj = pyproj.Proj(init="epsg:2790", preserve_units=True)    
    index, zones = createIndex('geo_export_e9d3582a-5b2b-4f57-a181-13de90251c84.shp')    
    
    if pid==0:
        records.next()
    reader = csv.reader(records)
    counts = {}
    
    for row in reader:
#         pdt = row[0].split(' ')[1].split(':')[0]
#         if pdt!='10':
#             continue
        #print row
        try:
            p = geom.Point(proj(float(row[18]), float(row[17])))
        except:
            #print("cant convert")
            continue
        
        
        zone = findZone(p, index, zones)
        if zone:
            counts[zone] = counts.get(zone, 0) + 1
    return counts.items()
    
rdd = sc.textFile('chi100k.csv')
counts = rdd.mapPartitionsWithIndex(processTrips)
counts = counts.reduceByKey(lambda x,y: x+y)
counts = counts.collect()
len(counts)
# Out:
# 71

# %%
countsPerComm = map(lambda x: (comm['community'][x[0]], x[1]), counts)
df = pd.DataFrame(countsPerComm).sort_values(1).set_index(0)
df.plot(kind='barh', title='Chicago Taxi Pickup Trips per Community', figsize=(8,24), fontsize=12, legend=False)
plt.axes().yaxis.grid(False)
# Out:
# C:\Users\Sunny\Anaconda2\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
df
# Out:
#                             1
# 0
# BURNSIDE                    1
# PULLMAN                     2
# BEVERLY                     2
# SOUTH CHICAGO               3
# SOUTH DEERING               3
# WEST LAWN                   3
# ASHBURN                     3
# WEST ENGLEWOOD              3
# WASHINGTON HEIGHTS          3
# WEST ELSDON                 4
# MORGAN PARK                 4
# MONTCLARE                   4
# WEST GARFIELD PARK          5
# AVALON PARK                 6
# GAGE PARK                   6
# ENGLEWOOD                   6
# EDISON PARK                 7
# FULLER PARK                 8
# CHICAGO LAWN                8
# CALUMET HEIGHTS             9
# ARCHER HEIGHTS             10
# CLEARING                   10
# AUBURN GRESHAM             10
# HERMOSA                    11
# WASHINGTON PARK            11
# ROSELAND                   12
# GREATER GRAND CROSSING     14
# EAST GARFIELD PARK         15
# NORTH LAWNDALE             16
# OAKLAND                    16
# ...                       ...
# AUSTIN                     42
# HUMBOLDT PARK              42
# NORWOOD PARK               47
# NORTH PARK                 60
# MCKINLEY PARK              84
# PORTAGE PARK               88
# LOWER WEST SIDE           106
# ARMOUR SQUARE             110
# KENWOOD                   113
# JEFFERSON PARK            135
# ALBANY PARK               217
# AVONDALE                  293
# ROGERS PARK               370
# HYDE PARK                 377
# WEST RIDGE                384
# IRVING PARK               395
# LINCOLN SQUARE            509
# NORTH CENTER              656
# EDGEWATER                1060
# LOGAN SQUARE             1253
# GARFIELD RIDGE           1637
# UPTOWN                   1717
# NEAR SOUTH SIDE          2314
# WEST TOWN                3755
# LINCOLN PARK             5626
# OHARE                    5950
# LAKE VIEW                7164
# NEAR WEST SIDE           8896
# LOOP                    22100
# NEAR NORTH SIDE         33132
#
# [71 rows x 1 columns]

# %%
countsPerComm = map(lambda x: (comm['community'][x[0]], x[1]), counts)
df = pd.DataFrame(countsPerComm).sort_values(1).set_index(0)
df.tail(20).plot(kind='barh', title='Chicago Top 20 Taxi Pickup Trips per Community', figsize=(8,8), fontsize=12, legend=False)
plt.axes().yaxis.grid(False)

# %%
countsPerComm = map(lambda x: (comm['community'][x[0]], x[1]), counts)
df = pd.DataFrame(countsPerComm).sort_values(1).set_index(0)
df.head(20).plot(kind='barh', title='Chicago Lowest 20 Taxi Pickup Trips per Community', figsize=(8,8), fontsize=12, legend=False)
plt.axes().yaxis.grid(False)
